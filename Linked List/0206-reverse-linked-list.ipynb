# %% [markdown]
# # <center> 206. Reverse Linked List </center>
#
#
# ## Problem Description
# [Click here](https://leetcode.com/problems/reverse-linked-list/description/)
#
#
# ## Intuition
# <!-- Describe your first thoughts on how to solve this problem. -->
# Reverse the list by changing the links between the nodes using pointers i.e set the next of each node to the previous node.
#
#
# ## Approach
# <!-- Describe your approach to solving the problem. -->
# - set prev = null to track the previous node
# - set cur = head to track the current node
# - loop until the last node
#     - store the next node in next pointer
#     - make the previous node as the next node of the current node
#     - make the current node as the previous node
#     - make the next node as the current node
# - return the previous node pointer as the head of the reversed list
#
#
# ## Complexity
# <!-- Add your time complexity here, e.g. $$O(n)$$ -->
# - Time complexity: O(loop) → O(total nodes) → O(n)
#
# <!-- Add your space complexity here, e.g. $$O(n)$$ -->
# - Space complexity: O(total new nodes created) → O(0) → O(1)
#
#
# ## Code

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next


class Solution:

    def reverseList(self, head: Optional[ListNode]) -> Optional[ListNode]:
        prev, cur = None, head
        while cur:
            next = cur.next
            cur.next = prev
            prev = cur
            cur = next
        return prev
