# %% [markdown]
# # <center> 101. Symmetric Tree </center>
#
#
# ## Problem Description
# [Click here](https://leetcode.com/problems/symmetric-tree/description/)
#
#
# ## Intuition
# <!-- Describe your first thoughts on how to solve this problem. -->
# A binary tree is symmetric if its​ left and right subtrees are mirror images.
#
# Two trees A and B are mirror images if:
# - their root values are equal
# - left subtree of A is mirror of right subtree of B
# - right subtree of A is mirror of left subtree of B
#
# To check if two trees are mirror images, do DFS.
#
#
# ## Approach
# <!-- Describe your approach to solving the problem. -->
# **Recursive Approach**
# - define a helper function to check if the subtrees are mirror
# dfs(tree1 node, tree2 node)
#   - check base cases
#     - if both trees are empty because empty trees are always mirror images
#     - if one of the trees is empty, return false because an empty and non-empty tree can't be mirror images
#     - check the above three conditions for the mirror tree and return the result
#
# **Iterative Approach**
# - create a stack and add the left and right child of the root
# - loop while stack is not empty
#     - pop stack two times to get the two subtrees (left and right) nodes
#     - if both nodes are null, continue the loop because empty trees are mirror images
#     - if one of the nodes is null, return false because an empty and non-empty tree can't be mirror images
#     - if the values of the nodes are not equal, return false
#     - else values are equal, push the children nodes in the following sequence to compare the mirror positions i.e node1 left child with node2 right child and vv
#     *node1 left child → node2 right child → node1 right child → node2 left child*
# - if the loop completes without returning false, the binary tree is symmetric, return true
#
#
# ## Complexity
# - Time complexity:
#   - Recursive Approach: O(n)
#     - *each node in both trees is visited at most once during DFS comparison*
#   - Iterative Approach: O(n)
#     - *each node is pushed and popped from the stack at most once*
# <!-- Add your time complexity here, e.g. $$O(n)$$ -->
#
# - Space complexity:
#   - Recursive Approach: O(recursion stack) → O(h) → O(n)
#     - *height (h) depends on the tree structure, balanced tree height is logn and skewed tree height is n*
#   - Iterative Approach: O(stack) → O(h) → O(n)
# <!-- Add your space complexity here, e.g. $$O(n)$$ -->
#
#
# ## Code

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right


class Solution:

    def isSymmetric(self, root: Optional[TreeNode]) -> bool:
        
        # recursive
        def dfs(node1: Optional[TreeNode], node2: Optional[TreeNode]) -> bool:
            if not node1 and not node2:
                return True
            if not node1 or not node2:
                return False
            return node1.val == node2.val and dfs(node1.left, node2.right) and dfs(node1.right, node2.left)

        return dfs(root.left, root.right)

        # iterative
        # stack = [root.left, root.right]
        # while stack:
        #     node1, node2 = stack.pop(), stack.pop()
        #     if not node1 and not node2:
        #         continue
        #     if not node1 or not node2:
        #         return False
        #     if node1.val != node2.val:
        #         return False
        #     stack.append(node1.left)
        #     stack.append(node2.right)
        #     stack.append(node1.right)
        #     stack.append(node2.left)
        # return True
