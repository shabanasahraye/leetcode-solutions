# %% [markdown]
# # <center> 894. All Possible Full Binary Trees </center>
#
#
# ## Problem Description
# [Click here](https://leetcode.com/problems/all-possible-full-binary-trees/description/)
#
#
# ## Intuition
# <!-- Describe your first thoughts on how to solve this problem. -->
# In a full binary tree:
# - each node has either 0 or 2 children
# - total number of nodes is odd
# - there are i nodes in the left subtree and n - i - 1 nodes in the right subtree, where i is odd
#     - *n = total nodes in the tree*
#     - *i ranges from 1 to n-2 in odd steps*
#
# A full binary tree can be divided into smaller full binary trees i.e. the problem can be divided into sub-problems. Use recursion.
#
# Use memoization (hashmap) to prevent redundant computations i.e to avoid generating the trees that are already generated.
#
# Note: Each node value is 0.
#
#
# ## Approach
# <!-- Describe your approach to solving the problem. -->
# ### Approach 1: Without Memoization
# - check base cases
#     - if n is even
#         - return an empty list because nodes in a full binary tree are odd
#     - if n is 1
#         - return a new tree with one node
# - set res = a list to store the full binary trees
# - for each odd i from 1 to n - 2
#     - *generate all possible left subtrees with i nodes*
#     - *generate all possible right subtrees with n - i - 1 nodes*
#     - for each pair of generated subtrees (left and right)
#         - create a root node and add the left and right subtrees to create a new full binary tree
#         - add the full binary tree root node to the list
# - return the list
#
# ### Approach 2: With Memoization
# - create a hashmap to store generated trees
# - define a helper function for memoization <br>
# *helper(n: number of nodes)*
#     - if trees for n nodes are already in the hashmap
#         - return the list of trees for n nodes
#     - if n is even
#         - return an empty list because nodes in a full binary tree are odd
#     - if n is 1
#         - return a new tree with one node
#     - set res = a list to store the new full binary trees
#     - for each odd i from 1 to n - 2
#         - *generate all possible left subtrees with i nodes*
#         - *generate all possible right subtrees with n - i - 1 nodes*
#         - for each pair of generated subtrees (left and right)
#             - create a root node and add the left and right subtrees to create a new full binary tree
#             - add the full binary tree to the list
#     - add the list of trees for n nodes to the hashmap
#     - return the list of trees for n node
# - call the helper() to generate full binary trees with n nodes
#
#
# ## Complexity
# <!-- Add your time complexity here, e.g. $$O(n)$$ -->
# - Time complexity:
#     - Approach 1: O(recursion depth/levels × recursive calls per level) → O(n × $2^n$)
#         - *recursion depth is proportional to how many times we reduce the number of nodes until reaching 1*
#         - *each level branches into multiple recursive calls to generate left and right subtrees*
#         - *many subtree sizes are recomputed repeatedly*
#     - Approach 2: O(unique subproblems + total full binary trees generated) → O(n + exponential) → O(exponential)
#         - *there are only O(n) different subtree sizes that can be generated*
#         - *each subtree size is computed once and then reused from the hashmap*
#         - *each valid tree still needs to be constructed and returned*
#
# <!-- Add your space complexity here, e.g. $$O(n)$$ -->
# - Space complexity:
#     - Approach 1: O(recursion stack + result list) → O(n + total full binary trees generated) → O(exponential)
#     - Approach 2: O(hashmap + recursion stack + result list) → O(n + n + total full binary trees generated) → O(n + exponential) → O(exponential)
#
#
# ## Code

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right


class Solution:

    def allPossibleFBT(self, n: int) -> List[Optional[TreeNode]]:
        
        # Approach 1: Without Memoization
        if n % 2 == 0:
            return []
        if n == 1:
            return [TreeNode(0)]
        res = []
        for i in range(1, n, 2):
            for left in self.allPossibleFBT(i):
                for right in self.allPossibleFBT(n - i - 1):
                    node = TreeNode(0, left, right)
                    res.append(node)
        return res


        # Approach 2: With Memoization
        # hashmap = {}

        # def helper(n: int) -> List[Optional[TreeNode]]:
        #     if n in hashmap:
        #         return hashmap[n]
        #     if n % 2 == 0:
        #         return []
        #     if n == 1:
        #         return [TreeNode(0)]
        #     res = []
        #     for i in range(1, n, 2):
        #         for left in helper(i):
        #             for right in helper(n - i - 1):
        #                 res.append(TreeNode(0, left, right))
        #     hashmap[n] = res
        #     return hashmap[n]
        
        # return helper(n)
