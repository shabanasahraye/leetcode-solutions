# %% [markdown]
# # <center> 100. Same Tree </center>
#
#
# ## Problem Description
# [Click here](https://leetcode.com/problems/same-tree/description/)
#
#
# ## Intuition
# <!-- Describe your first thoughts on how to solve this problem. -->
# Traverse both trees simultaneously and compare node values and structure.
#
#
# ## Approach
# <!-- Describe your approach to solving the problem. -->
# - check base cases
#   - if both trees are empty, return true because they are the same
#   - if any one of the trees is empty or their values are not equal, return false
# - else both trees are non-empty, recursively check their left and right subtrees
# *(it will return true if both are identical and the nodes have the same value else false)*
#
#
# ## Complexity
# - Time complexity: O(min(smaller tree nodes, bigger tree nodes)) → O(min(m, n)) → O(m)
#  - *each node is visited at most once (until mismatch)*
#  - *at most we traverse the smaller tree completely*
# <!-- Add your time complexity here, e.g. $$O(n)$$ -->
#
# - Space complexity: O(recursion stack) → O(min(tree1 height, tree2 height) → O(min(h1, h2)) → O(h) → O(n)
#     - *height (h) depends on the tree structure, balanced tree height is logn and skewed tree height is n*
# <!-- Add your space complexity here, e.g. $$O(n)$$ -->
#
#
# ## Code

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right


class Solution:

    def isSameTree(self, p: Optional[TreeNode], q: Optional[TreeNode]) -> bool:
        if not p and not q:
            return True
        if not p or not q or p.val != q.val:
            return False
        return self.isSameTree(p.left, q.left) and self.isSameTree(p.right, q.right)
