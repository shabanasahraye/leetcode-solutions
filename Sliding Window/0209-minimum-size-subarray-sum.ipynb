# %% [markdown]
# # <center> 209. Minimum Size Subarray Sum </center>
#
#
# ## Problem Description
# [Click here](https://leetcode.com/problems/minimum-size-subarray-sum/description/)
#
#
# ## Intuition
# <!-- Describe your first thoughts on how to solve this problem. -->
# We need to find a minimum size subarray with sum >= target.
#
# Use the sliding window approach
#     - each time, add an element to the right of the window
#     - when you get a valid window (i.e window sum >= target), search for a small window by removing elements from the left until the window becomes invalid
#
#
# ## Approach
# <!-- Describe your approach to solving the problem. -->
# - set res = a large number to track the minimum window/subarray size
# - set pre_sum = 0 to track the prefix sum (window sum)
# - set left pointer l = 0, right pointer r = 0 to track the left and right sides of window
# - traverse the array, *you can use the right pointer r or any other pointer for traversal*
#     - add an element to the right of window by adding the current element to pre_sum
#     - while the current window is valid
#         - update res by taking min of current window size and the previous minimum
#         - remove an element from the left of the window by subtracting the element at position l from pre_sum
#         - move the left pointer
#     - move right pointer
#         - *will auto-update in for-loop*
# - return res if you found a minimum window, else 0
#
#
# ## Complexity
# <!-- Add your time complexity here, e.g. $$O(n)$$ -->
# - Time complexity: O(array traversal) → O(n)
#
# <!-- Add your space complexity here, e.g. $$O(n)$$ -->
# - Space complexity: O(1)
#
#
# ## Code

# %%
class Solution:

    def minSubArrayLen(self, target: int, nums: List[int]) -> int:
        res = float('inf')
        pre_sum = 0
        l = 0
        for r in range(len(nums)):
            pre_sum += nums[r]
            while pre_sum >= target:
                res = min(res, r - l + 1)
                pre_sum -= nums[l]
                l += 1
        return res if res != float('inf') else 0
