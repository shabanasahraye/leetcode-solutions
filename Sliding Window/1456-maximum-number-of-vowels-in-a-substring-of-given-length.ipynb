# %% [markdown]
# # <center> 1456. Maximum Number of Vowels in a Substring of Given Length </center>
#
#
# ## Problem Description
# [Click here](https://leetcode.com/problems/maximum-number-of-vowels-in-a-substring-of-given-length/description/)
#
#
# ## Intuition
# <!-- Describe your first thoughts on how to solve this problem. -->
# Use the sliding window approach.
#
# Keep a window of size k and track the number of vowels in it. Keep moving the window and update the number of vowels while moving.
#
#
# ## Approach
# <!-- Describe your approach to solving the problem. -->
# - set res = 0 to track the window with max vowels
# - set count = 0 to count vowels in the current window
# - set vowels = a hashset containing all vowel letters
# - set left pointer l = 0, and right pointer r = 0 to track the left and right sides of the window
# - traverse the string, *you can use the right pointer r or another pointer for traversal*
#     - if current character is a vowel, add it to the window by incrementing the count
#     - if window is invalid i.e window size > k, slide the window
#         - if the left character is a vowel, decrement the count
#         - move the left pointer
#     - the window is valid now
#         - take max of the current window vowels count and previous max count and update res
#         - move the right pointer
#             - *will auto-update in for loop*
# - return res
#
#
# ## Complexity
# <!-- Add your time complexity here, e.g. $$O(n)$$ -->
# - Time complexity: O(string traversal) → O(n)
#
# <!-- Add your space complexity here, e.g. $$O(n)$$ -->
# - Space complexity: O(hashset) → O(vowels) → O(5) → O(1)
#
#
# ## Code

# %%
class Solution:

    def maxVowels(self, s: str, k: int) -> int:
        res = 0
        count = 0
        vowels = ('a', 'e', 'i', 'o', 'u')
        l, r = 0, 0
        for r in range(len(s)):
            if s[r] in vowels:
                count += 1
            if r - l + 1 > k:
                if s[l] in vowels:
                    count -= 1
                l += 1
            res = max(res, count)
        return res
