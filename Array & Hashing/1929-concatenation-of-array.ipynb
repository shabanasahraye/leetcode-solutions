# %% [markdown]
# # <center> 1929. Concatenation of Array </center>
#
#
# ## Problem Description
# [Click here](https://leetcode.com/problems/concatenation-of-array/description/)
#
#
# ## Intuition
# <!-- Describe your first thoughts on how to solve this problem. -->
# 1. concatenate
# 2. repeat
# 3. extend()
# 4. append()
#
#
# ## Approach
# <!-- Describe your approach to solving the problem. -->
# **concatenate**
# - concatenate by using the + operator and return the result
#
# **repeat**
# - use array * k to create a kn array
# *k is the number of times you want to repeat the array, here k is 2*
#
# **extend()**
# - use extend() and add the input array at the end of the itself
# - return the input array
#
# **append()**
# - traverse the input array
#     - add the current number in the input array at the end of the array
# - return the input array
#
#
# ## Complexity
# <!-- Add your time complexity here, e.g. $$O(n)$$ -->
# - Time complexity:
#     - concatenat: O(n)
#     - repeat: O(2n) → O(n)
#     - extend: O(n)
#     - append: O(n)
#
# <!-- Add your space complexity here, e.g. $$O(n)$$ -->
# - Space complexity:
#     - concatenate: O(n + n) → O(n)
#     - repeat: O(2n) → O(n)
#     - extend: O(n)
#     - append: O(n)
#
#
# ## Code

# %%
class Solution:
    
    def getConcatenation(self, nums: List[int]) -> List[int]:
        
        # return nums + nums

        # return nums * 2

        # nums.extend(nums)
        # return nums

        for i in range(len(nums)):
            nums.append(nums[i])
        return nums
