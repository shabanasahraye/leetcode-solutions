# %% [markdown]
# # <center> 349. Intersection of Two Arrays </center>
#
#
# ## Problem Description
# [Click here](https://leetcode.com/problems/intersection-of-two-arrays/description/)
#
#
# ## Intuition
# <!-- Describe your first thoughts on how to solve this problem. -->
# The intersection of two arrays is the same as the intersection of two sets.
#
# - **Approach 1: & Operator**
#     - find the intersection using & operator
#     - *this solution involves too many conversions*
#
# - **Approach 2: Traversal**
#     - find the intersection using traversal
#
#
# ## Approach
# <!-- Describe your approach to solving the problem. -->
# ### Approach 1: & Operator
# - Convert the arrays to sets to remove duplicates, find the intersection using & operator, convert the result to a list, and return it
#
# ### Approach 2: Traversal
# - set res = a list to store the intersection
# - convert the array1 to a set to remove duplicates and search in O(1) time
# - traverse array2
#     - if the current number in array2 is in the array1 set
#         - add it to the result list
#         - remove the number from the array1 set to avoid duplicates in the result
# - return the result list
#
#
# ## Complexity
# <!-- Add your time complexity here, e.g. $$O(n)$$ -->
# - Time complexity:
#     - Operator Approach: O(converting array1 to set + converting array2 to set + intersection + converting result to list) → O(m + n + min(m, n) + min(m, n)) → O(m + n)
#     - Traversal Approach: O(converting array1 to set + traversing array2) → O(m + n)
#
# <!-- Add your space complexity here, e.g. $$O(n)$$ -->
# - Space complexity:
#     - Operator Approach: O(array1 set + array2 set + result) → O(m + n)
#     - Traversal Approach: O(array1 set) → O(array1 size) → O(m)
#
#
# ## Code

# %%
class Solution:

    def intersection(self, nums1: List[int], nums2: List[int]) -> List[int]:
        
        # Approach 1: & Operator
        return list(set(nums1) & set(nums2))
        
        # Approach 2: Traversal
        res = []
        seen = set(nums1)
        for n in nums2:
            if n in seen:
                res.append(n)
                seen.remove(n)
        return res
