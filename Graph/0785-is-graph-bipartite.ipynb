# %% [markdown]
# # <center> 785. Is Graph Bipartite? </center>
#
#
# ## Problem Description
# [Click here](https://leetcode.com/problems/is-graph-bipartite/description/)
#
#
# ## Intuition
# <!-- Describe your first thoughts on how to solve this problem. -->
# The graph is bipartite if we can divide the nodes into two sets (A, B) such that no nodes in the same set are neighbors (have an edge connecting them). For example, if node 0 has neighbors 2 and 3 then node 0 should be in a separate set and nodes 2, 3 in a separate one.
#
# Use BFS to assign every node to one of two sets. Every neighbor must be placed in the opposite set. If two adjacent nodes must be placed in the same set, the graph is not bipartite.
#
# Instead of using two sets to put the nodes, mark/color the nodes. <br>
# - color white (0) → not placed in a set <br>
# - color blue (1) → set A <br>
# - color red (-1) → set B
#
#
# # Approach
# <!-- Describe your approach to solving the problem. -->
# - set n = total number of nodes
# - initialize an array of size n with zeroes to color the nodes
#     - *index = node*
#     - *value = color*
# - define a helper function for BFS <br>
# *bfs(node)*
#     - if the node has been colored (value = 1 or -1), it has been visited and placed in a set
#         - return True
#     - create a queue and add the node
#     - color the node blue (1)
#     - while q is not empty
#         - pop a node from the q to get current level node
#         - visit the neighbors of the current node
#             - if the neighbor is colored and has the same as the current node, the neighbor node will be placed in the same set
#                 - return false
#             - if the neighbor is not colored
#                 - add it to the queue
#                 - color the neighbor with the opposite color i.e `-color[current node]`
# - for each node in the graph
#     - if the node is not colored (not placed in a set)
#         - do BFS to check if we can place the node and its neighbors in separate sets, if we can't, return False
# - if the loop completes without returning false, the graph is bipartite, return true
#
#
# ## Complexity
# <!-- Add your time complexity here, e.g. $$O(n)$$ -->
# - Time complexity: O(graph BFS) → O(adjacency list BFS) → O(V + E)
#     - *V = total vertices/nodes*
#     - *E = total edges*
#     - *each node is visited once and each edge is processed at most once during BFS*
#
# <!-- Add your space complexity here, e.g. $$O(n)$$ -->
# - Space complexity: O(color array + BFS queue) → O(total nodes + deepest level nodes) → O(V + V) → O(V)
#     - *the color array stores the color of each node*
#     - *the BFS queue stores at most V nodes*
#
#
# ## Code

# %%
class Solution:

    def isBipartite(self, graph: List[List[int]]) -> bool:
        n = len(graph)
        color = [0] * n

        def bfs(node: int) -> bool:
            if color[node] != 0:
                return True
            q = deque([node])
            color[node] = 1
            while q:
                cur = q.popleft()
                for neighbor in graph[cur]:
                    if color[neighbor] == color[cur]:
                        return False
                    if color[neighbor] == 0:
                        q.append(neighbor)
                        color[neighbor] = -color[cur]
            return True
        
        for node in range(n):
            if color[node] == 0 and not bfs(node):
                return False
        return True
