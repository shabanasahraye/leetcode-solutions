# %% [markdown]
# # <center> 953. Verifying an Alien Dictionary </center>
#
#
# ## Problem Description
# [Click here](https://leetcode.com/problems/verifying-an-alien-dictionary/description/)
#
#
# ## Intuition
# <!-- Describe your first thoughts on how to solve this problem. -->
# We are given a list of words and we need to check if the words are in sorted order according to the given key.
#
# The words are sorted if:
# - next word is not a prefix of the previous word
# - order/index of the first different letter in the next word is greater than the previous word
#
# For example:
# - words = ['hello', 'hi'] <br>
# - key/order = 'hlabcdefgijkmnopqrstuvwxyz' <br>
# - answer is true because:
#     - hi is not a prefix of hello
#     - the first differing letters of the two words are e and i, and the index of i in the key is 9 which is greater than e (6)
#
# Use a hashmap to map the letters to their order/index. Traverse the words and check the above conditions. Return false if either condition doesn't hold.
#
# ## Approach
# <!-- Describe your approach to solving the problem. -->
# - map each letter in the alien alphabet to its index
# - loop from 0 to n - 2 to compare adjacent words
#     - get current and next words
#     - loop in range 0 to the length of the current word to compare the letters
#         - if the current index reaches the length of the next word, the next word is a prefix of the current word
#             - return false
#         - if current letter of current word is not the same as the next word's letter, we get the first different letter
#             - if the order of next word's letter is smaller, the words are not sorted
#                 - return false
#             - else the words are sorted, we don't need to check the rest of the letters, break the loop
# - if the loop completes without returning false, all words are sorted, return true
#
#
# ## Complexity
# <!-- Add your time complexity here, e.g. $$O(n)$$ -->
# - Time complexity: O(order mapping + words comparison) → O(order key size + total words * max word length) → O(26 + n * 20) → O(n)
#
# <!-- Add your space complexity here, e.g. $$O(n)$$ -->
# - Space complexity: O(order hashmap) → O(order key size) → O(26) → O(1)
#
#
# ## Code

# %%
class Solution:

    def isAlienSorted(self, words: List[str], order: str) -> bool:
        order_index = {c:i for i, c in enumerate(order)}
        for i in range(len(words) - 1):
            w1, w2 = words[i], words[i+1]
            for j in range(len(w1)):
                if j == len(w2):
                    return False
                if w1[j] != w2[j]:
                    if order_index[w2[j]] < order_index[w1[j]]:
                        return False
                    break
        return True
