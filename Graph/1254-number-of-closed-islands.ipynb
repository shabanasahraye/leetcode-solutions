# %% [markdown]
# # <center> 1254. Number of Closed Islands </center>
#
#
# ## Problem Description
# [Click here](https://leetcode.com/problems/number-of-closed-islands/description/)
#
#
# ## Intuition
# <!-- Describe your first thoughts on how to solve this problem. -->
# An island is closed if it is surrounded by water i.e it is not on the boundary.
#
# The grid can be viewed as a graph where each land cell is connected to its 4 neighbors. Use DFS to find each island (connected component). If DFS reaches the boundary, the island is not closed and vice versa.
#
#
# ## Approach
# <!-- Describe your approach to solving the problem. -->
# - set res = 0 to track the number of closed islands
# - set m = total rows, n = total columns
# - define a helper function for DFS <br>
# *dfs(row, column)*
#     - if the indices are out of bounds, the cell doesn't belong to a closed island, return 0
#     - if the cell value is not 0, it is either a water cell or a visited land cell
#         - return 1
#     - else cell value is 0 i.e it is an unvisited land cell
#         - mark it visited
#             - *here, we are updating the cell value to mark it as visited, we can also use a hashset for marking*
#             - *0 = land cell, 1 = water cell, 2 = visited land cell*
#         - explore all 4 neighbors (top, bottom, left, right) using DFS and return the minimum of all DFS results
#             - *(the island is closed only if all recursive DFS calls return 1)*
# - traverse all cells <br>
# *for each cell on the grid*
#     - if the cell is an unvisited land cell (value = 0)
#         -  do DFS to determine whether it belongs to a closed island and update res
# - return res
#
#
# ## Complexity
# <!-- Add your time complexity here, e.g. $$O(n)$$ -->
# - Time complexity: O(graph traversal) → O(adjacency matrix DFS) → O(V) → O(m × n)
#     - *V = total vertices/nodes = total grid cells = m × n*
#     - *DFS visits each land cell at most once*
#
# <!-- Add your space complexity here, e.g. $$O(n)$$ -->
# - Space complexity: O(DFS recursion stack) → O(recursion depth) → O(V) → O(m × n)
#     - *recursion depth is V because DFS may visit every land cell before returning (worst case: the entire grid is one island)*
#
#
# ## Code

# %%
class Solution:
    
    def closedIsland(self, grid: List[List[int]]) -> int:
        res = 0
        m, n = len(grid), len(grid[0])

        def dfs(r: int, c: int) -> int:
            if r < 0 or r == m or c < 0 or c == n:
                return 0
            if grid[r][c] != 0:
                return 1
            grid[r][c] = 2
            return min(dfs(r - 1, c), dfs(r + 1, c), dfs(r, c - 1), dfs(r, c + 1))

        for row in range(m):
            for col in range(n):
                if grid[row][col] == 0:
                    res += dfs(row, col)
        return res
