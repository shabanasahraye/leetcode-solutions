# %% [markdown]
# # <center> 79. Word Search </center>
#
#
# ## Problem Description
# [Click here](https://leetcode.com/problems/word-search/description/)
#
#
# ## Intuition
# <!-- Describe your first thoughts on how to solve this problem. -->
# We are given a 2d board and a word. Each board cell represents a letter. The task is to check if the word can be constructed from the letters of adjacent cells.
#
# Use backtracking to explore all possible paths starting from each cell. At every step, try matching the next character of the word by moving to one of the four adjacent cells.
#
# To avoid revisiting the same cell, mark it as visited before exploring its neighbors and unmark it after. For marking, either use a hash set or temporarily replace the cell letter with a special character '*' (we can use any character except an English letter).
#
# ## Approach
# <!-- Describe your approach to solving the problem. -->
# - set m = no. of rows and n = no. of columns
# - define a helper function for backtracking <br>
# *backtrack(row, column, current character index)*
#     - if row or col is out of bounds
#       - return false
#     - if the cell has been visited or the cell letter is not the same as the current character in the word
#       - return false
#     - if the current index is the last
#       - return true because we've found the word
#     - store the current cell letter and mark the current cell as visited
#     - backtrack to check if we can find the word by exploring the 4 neighboring paths (bottom, top, right, left) and store the result
#     - unmark the cell after backtracking
#     - return the backtracking result
# - for each cell in the board
#   - do backtracking and return true if the word is found
# - if the loop completes without returning true, the word doesn't exist in the board, return false
#
#
# ## Complexity
# <!-- Add your time complexity here, e.g. $$O(n)$$ -->
# - Time complexity: O(board traversal * backtracking) → O(rows * columns * total recursive calls * work per call) → O(rows * columns * total recursion tree nodes * work per call) → O(m * n * 4 * $3^{w - 1}$ * constant) → O(m * n * $3^w$)
#    *we can start the search from every cell, giving m × n possible starting positions*
#   - *recursion depth is w because we process one character per level*
#   - *branching factor varies but follows the pattern (4, 3, 3, ...), so the recursion tree contains at most 4 × $3^{w − 1}$ nodes because:*
#     - *from the starting cell, we can explore up to 4 directions*
#     - *after the first move, we have at most 3 choices because we can't revisit the previous cell*
#   - *total recursive calls = total recursion tree nodes = 4 × $3^{w - 1}$*
#   - *work per call is constant because of constant-time operation*
#
#
# <!-- Add your space complexity here, e.g. $$O(n)$$ -->
# - Space complexity: O(recursion stack) → O(recursion depth) → O(w)
#
#
# ## Code

# %%
class Solution:

    def exist(self, board: List[List[str]], word: str) -> bool:
        m, n = len(board), len(board[0])

        def backtrack(r: int, c: int, i: int) -> bool:
            if r < 0 or r == m or c < 0 or c == n:
                return False
            if  board[r][c] == '*' or board[r][c] != word[i]:
                return False
            if i == len(word) - 1:
                return True
            cache = board[r][c]
            board[r][c] = '*'
            res = backtrack(r + 1, c, i + 1) or \
                  backtrack(r - 1, c, i + 1) or \
                  backtrack(r, c + 1, i + 1) or \
                  backtrack(r, c - 1, i + 1)
            board[r][c] = cache
            return res
            
        for r in range(m):
            for c in range(n):
                if backtrack(r, c, 0):
                    return True
        return False
