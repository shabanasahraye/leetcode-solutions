# %% [markdown]
# # <center> 46. Permutations </center>
#
#
# ## Problem Description
# [Click here](https://leetcode.com/problems/permutations/description/)
#
#
# ## Intuition
# <!-- Describe your first thoughts on how to solve this problem. -->
# We are given an array of unique elements and need to generate all possible permutations.
#
# A permutation is a rearrangement of the elements. For n elements, there are n! possible permutations.
#
# This is a backtracking problem because we need to explore all possible choices for each position.
#
# Use backtracking to explore all possible arrangements and generate every permutation
# - to generate all permutations, fix one position at a time and try every remaining element in that position
# - use swapping to place an element at the current position
# - recursively generate permutations for the remaining positions
# - swap back to restore the original arrangement and try the next choice
#
#
# ## Approach
# <!-- Describe your approach to solving the problem. -->
# - set n = total number of elements
# - create a result list to store the permutations
# - define a helper function for backtracking <br>
# *backtrack(start index)*
#     - if current start index is same as n, we have considered all elements and current rearrangement/permutation is valid
#         - add a copy of the current permutation to the result list and return
#               - *add the copy to avoid overwriting during future backtracking because path is a mutable list and will be modified during recursion*
#     - for each index in the range start index to n in the input list
#         - swap the start index and current index element
#             - *this is to fix the current element at the current position*
#         - backtrack to explore permutations for the remaining positions
#         - swap the start index and current index element again
#             - *this is to restore the original arrangement and try the next element*
# - start backtracking from index 0 as the start position
# - return the result list
#
#
# ## Complexity
# <!-- Add your time complexity here, e.g. $$O(n)$$ -->
# - Time complexity: O(backtracking) → O(total recursive calls × work per call) → O(total states explored × work per call) → O(total permutations × copy cost) → O(n! × n) → O(n × n!)
#   - *branching factor is variable because the number of available choices decreases at each level*
#   - *as the branching factor is variable, total recursive calls ≈ total states explored*
#   - *copy cost O(n) because each valid permutation has n elements*
#
# <!-- Add your space complexity here, e.g. $$O(n)$$ -->
# - Space complexity: O(recursion stack + output list) → O(recursion depth + total permutations × permutation size) → O(n + n! × n) → O(n × n!)
#   - *recursion depth is n because we fix one position per level*
#   - *output stores all permutations, each of size n*
#
#
# ## Code

# %%
class Solution:

    def permute(self, nums: List[int]) -> List[List[int]]:
        n = len(nums)
        res = []

        def backtrack(start: int) -> None:
            if start == n:
                res.append(nums.copy())
                return
            for i in range(start, n):
                nums[start], nums[i] = nums[i], nums[start]
                backtrack(start + 1)
                nums[start], nums[i] = nums[i], nums[start]

        backtrack(0)
        return res
