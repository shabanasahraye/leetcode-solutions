# %% [markdown]
# # <center> 1834. Single-Threaded CPU </center>
#
#
# ## Problem Description
# [Click here](https://leetcode.com/problems/single-threaded-cpu/description/)
#
#
# ## Intuition
# <!-- Describe your first thoughts on how to solve this problem. -->
# Each task has two values: start time and processing time.
#
# Task processing priority
# - tasks with the earliest start time are processed first
# - if the start time is the same, the task with the shortest processing time is processed first
# - if the processing time is the same, the task with the smallest index is processed first
#
# Tasks are not processed simply based on the earliest start time. Start time only decides when a task becomes available, not the execution order. Once tasks are available, we always pick the one with the smallest processing time (then smallest index).
#
# Sort tasks based on the start time so tasks are considered in the order they become available for processing.
#
# To get the shortest processing time task first, use min heap because it returns the min value in O(1) time.
#
#
# ## Approach
# <!-- Describe your approach to solving the problem. -->
# - traverse the tasks list and add an index to each task
#     - *each task will have three values now: start time, processing time, and index*
#     - *this is to preserve the index (order) because the index (order) will be changed after sorting*
# - sort tasks based on the start time
# - create a result list to store the order of processed tasks
# - create a min heap
# - set i = 0 to track the current task index
# - set time = smallest start time i.e start time of the first task to track current finish time
# - loop until all tasks are processed
#     - if the heap is empty, there are no available tasks
#         - update the current finish time i.e move the current CPU time to the next task's start time
#     - else heap is not empty
#         - push all tasks with start time <= current finish time
#         - push processing time and task index and increment i after every push
#     - pop heap to get the processing time and index of the task with the min processing time
#     - add the processing time to the current finish time
#     - add the index of the task to the result list
# - return res
#
#
# ## Complexity
# <!-- Add your time complexity here, e.g. $$O(n)$$ -->
# - Time complexity: O(assigning index + sort + tasks traversal * heap push/pop) → O(n + nlogn + n * log(heap size)) → O(n + nlogn + nlogn) → O(nlogn)
#     - *heap size can be at most n*
#     - *each task is pushed into the heap once and popped from the heap once*
#     - *the inner while loop will not run n times for each outer loop iteration*
#
# <!-- Add your space complexity here, e.g. $$O(n)$$ -->
# - Space complexity: (sort + heap + result list) → O(n + n + n) → O(n)
#
#
# ## Code

# %%
class Solution:

    def getOrder(self, tasks: List[List[int]]) -> List[int]:
        for i, t in enumerate(tasks):
            t.append(i)
        tasks.sort(key=lambda t: t[0])
        res, min_heap = [], []
        i, time = 0, tasks[0][0]
        while len(res) < len(tasks):
            if not min_heap:
                time = max(time, tasks[i][0])
            while i < len(tasks) and time >= tasks[i][0]:
                heappush(min_heap, [tasks[i][1], tasks[i][2]])
                i += 1
            process_time, index = heappop(min_heap)
            time += process_time
            res.append(index)
        return res
